# %%
# SESSION 17 – NVIDIA (RRT)

# Distance of new node from goal (example)
distance_to_goal = 0.3  # in meters

# Goal radius
goal_radius = 0.4  # in meters

# Check goal connection
if distance_to_goal <= goal_radius:
    print("Goal Connected")
else:
    print("Goal Not Connected")
